# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/code/lawsdiv`

# %%
using DataFrames, DataFramesMeta, GLM
using Statistics, StatsBase
using FFTW
using CSV
using Plots

# %%
# Import synthetic data
synth_data = CSV.read("./Data/synthetic/SGLV_dense.csv", DataFrame)

# Drop unnecessary columns
select!(synth_data, Not([:trajectory]))
first(synth_data, 5)
# Out:
# 5×3 DataFrame
#  Row │ time     variable  value
#      │ Float64  Int64     Float64
# ─────┼──────────────────────────────
#    1 │     0.0         1  0.125779
#    2 │     0.0         2  0.0629134
#    3 │     0.0         3  0.34451
#    4 │     0.0         4  0.564486
#    5 │     0.0         5  0.137538

# %%
# Consider only steady state regime
# I also consider only a portion of it since using all of the samples makes the computation heavier without
# having any difference in the final result
df = synth_data[(synth_data.time .> 5000) .& (synth_data.time .< 5500),:];

# There is a bug in the synthetic data since they go infinitely negative. They should be the species that go extinct
# which should be discarded from further analysis.

# Get the variables that are always non-negative
nonneg_vars = combine(groupby(df, :variable)) do subdf
    (; variable = subdf.variable[1], all_nonneg = all(>(0), subdf.value))
end

# Filter the variables where all values are > 0
allowed = nonneg_vars.variable[nonneg_vars.all_nonneg .== true]

# Filter the original DataFrame
df_filtered = filter(row -> row.variable in allowed, df);

# %% [markdown]
# # PSD analysis using NFFT

# %%
# Set initial parameters
N = length(unique(df_filtered.time))
otu_ids = unique(df_filtered.variable) # Get otu_ids
t_indices = df_filtered.time .- minimum(df_filtered.time)
fs = 1  # sampling rate is 1 day
frequencies = (0:N-1) * fs/N # Frequency domain
otu_count = 0 # Needed for normalization
mean_S = zeros(N)  # initialize array

for otu in otu_ids
    x = collect(filter(row -> row.variable == otu, df_filtered).value)
    x .-= mean(x)

    # Some species remains at very low abundance so their fluctuations are essentially null. This means that their signal 
    # is seen as constant which means that all the frequencies are almost null and so is their power spectrum.
    if std(x) < 1e-10
        println("Skipping $otu — near-constant signal")
        continue
    end

    # Compute FFT
    fhat = fft(x)
    power = abs2.(fhat)
    norm_factor = sum(power)

    # Compute PSD
    S = power ./ N
    mean_S .+= S ./ norm_factor
end

# Take only positive frequencies
fc = findfirst(x -> x > 0, frequencies)
frequencies = frequencies[fc:end]
mean_S = mean_S[fc:end];
# Out:
# Skipping 2 — near-constant signal
# Skipping 10 — near-constant signal
# Skipping 11 — near-constant signal
# Skipping 14 — near-constant signal
# Skipping 15 — near-constant signal
# Skipping 18 — near-constant signal
# Skipping 21 — near-constant signal
# Skipping 22 — near-constant signal
# Skipping 23 — near-constant signal
# Skipping 26 — near-constant signal
# Skipping 29 — near-constant signal
# Skipping 32 — near-constant signal
# Skipping 41 — near-constant signal
# Skipping 42 — near-constant signal
# Skipping 46 — near-constant signal
# Skipping 48 — near-constant signal
# Skipping 49 — near-constant signal
# Skipping 50 — near-constant signal
# Skipping 52 — near-constant signal
# Skipping 53 — near-constant signal
# Skipping 54 — near-constant signal
# Skipping 56 — near-constant signal
# Skipping 58 — near-constant signal
# Skipping 62 — near-constant signal
# Skipping 63 — near-constant signal
# Skipping 65 — near-constant signal
# Skipping 66 — near-constant signal
# Skipping 69 — near-constant signal
# Skipping 74 — near-constant signal
# Skipping 78 — near-constant signal
# Skipping 79 — near-constant signal
# Skipping 81 — near-constant signal
# Skipping 82 — near-constant signal
# Skipping 87 — near-constant signal
# Skipping 88 — near-constant signal
# Skipping 90 — near-constant signal
# Skipping 91 — near-constant signal
# Skipping 92 — near-constant signal
# Skipping 93 — near-constant signal
# Skipping 94 — near-constant signal
# Skipping 100 — near-constant signal

# %%
# Take logs
log_k = log10.(frequencies)
log_S = log10.(mean_S)

# Put into a DataFrame and fit linear model: log_S ~ log_k
plot_df = DataFrame(log_k=log_k, log_S=log_S)
model = lm(@formula(log_S ~ log_k), plot_df)

# Extract the slope and intercept
coeffs = coef(model)
slope = coeffs[2]
intercept = coeffs[1]

println("Estimated slope: ", slope)
println("Intercept: ", intercept)

# Plot results
plot(log_k, log_S, label=:none, xlabel="log₁₀(frequency)", ylabel="log₁₀(power)", legend=:bottomleft,
    title="Mean PWD of dense SGLV")
plot!(log_k, predict(model), label="Fit: slope = $(round(slope, digits=2))", lw=2)
# Out:
# Estimated slope: -0.4162476940773197
# Intercept: -4.4562918670075495

# %%
savefig("./Images/psd_SGLV_dense.png")
# Out:
# "/home/luca/code/lawsdiv/Images/psd_SGLV_dense.png"
